# %%
a1 = float(input("dau diem a1 he so 1:"))
b1 = float(input("dau diem b1 he so 1:"))
c1 = float(input("dau diem c1 he so 1:"))
a2 = float(input("dau diem a2 he so 2:"))
b2 = float(input("dau diem b2 he so 2:"))
a3 = float(input("dau diem a"))
