# %%
#Bai1:
a = int(input("Nhập số nguyên a:"))#nhập giá trị
b = 2 * a
print("Giá trị số nguyên b bằng 2 lần số nguyên a:",b)#xuất giá trị
# Out:
# Giá trị số nguyên b bằng 2 lần số nguyên a: 1136

# %%
#Bai2:
chieu_dai=12345
chieu_rong=5789
pi=3.14
r=chieu_rong / 2
S_hcn = chieu_dai * chieu_dai
S_hcn = round(S_hcn,2)
S_tron = pi * r * r
S_tron = round(S_tron,2)
S_con_lai = S_hcn -S_tron
S_con_lai = round(S_con_lai,2)
print("Diện tích hình chữ nhât là :",S_hcn)
print("Diện tích hình tròn là :",S_tron)
print("Diện tích phần còn lại là:",S_con_lai)
# Out:
# Diện tích hình chữ nhât là : 152399025
# Diện tích hình tròn là : 26307328.98
# Diện tích phần còn lại là: 126091696.02

# %%
#Bai3:
c = input("Nhập vào một ký tự:")
if   c.isupper():#Nếu c là chữ in hoa
    print("Chữ cái thường:",c.lower())
elif c.islower():#Nếu c là chữ thường
    print("Chữ cái in hoa:",c.upper())
# Out:
# Chữ cái in hoa: G

# %%
#Bai4:
c = input("Nhập một ký tự")
if c.isalpha():#nếu c là một chữ cái
    print(f"{c} là ký tự alphabet.")
else :#nếu c không phải chữ cái
    print(f"{c} không phải là ký tự alphabet.")
# Out:
# A là ký tự alphabet.

# %%
#Bai5:
c = input("Nhập một chữ cái hoa (A-Z): ")

if 'A' <= c <= 'Z':
    if c == 'A':
        print("'A' là trường hợp đặc biệt")#TH đặc biệt
    else:
        c_thuong = chr(ord(c.lower()) - 1)#chữ thường đứng liền trước
        print("Chữ cái thường liền trước là:", c_thuong)
# Out:
# Chữ cái thường liền trước là: f

# %%
#Bài 6
a = float(input("Nhập cạnh a:"))
b = float(input("Nhập cạnh b:"))
c = float(input("Nhập cạnh c:"))
if (a > 0 and b > 0 and c> 0) and \
(a + b > c and a + c > b and b + c > a):
    p = (a + b + c) / 2 
    try:
        S = math.sqrt(p * (p - a) * (p - b) * (p - c))
        print(f"Đây là 3 cạnh của tam giác.")
        print(f"Diện tích của tam giác là: {S:.1f}")
    except ValueError:
        print("Có lỗi trong quá trình tính toán diện tích.")
else:
    print("Không phải 3 cạnh của tam giác.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       7 p = (a + b + c) / 2
#       8 try:
# ----> 9     S = math.sqrt(p * (p - a) * (p - b) * (p - c))
#      10     print(f"Đây là 3 cạnh của tam giác.")
#      11     print(f"Diện tích của tam giác là: {S:.1f}")
#
# NameError: name 'math' is not defined

# %%
#Bai 7
chuoi_ky_tu = "2,3,5,r,y,6,8,1,5.5,y,g,s,v,b,k,n,f,e,w,2,4,9"
ky_tu_thu_5 = chuoi_ky_tu[5]
ky_tu_thu_9 = chuoi_ky_tu[8]
print("Ky tu thu 5 la:" , ky_tu_thu_5)
print("Ky tu thu 9 la:" , ky_tu_thu_9)

# %%
#Bai8
def tinh_tien_truoc_vat(kwh):
    # các mốc và đơn giá (đồng/kWh)
    caps = [(50, 1984),
            (50, 2050),
            (100, 2380),
            (100, 2998),
            (100, 3350),
            (None, 3460)]  # None = phần còn lại
    remaining = kwh
    total = 0
    for cap, price in caps:
        if remaining <= 0:
            break
        if cap is None:
            used = remaining
        else:
            used = min(remaining, cap)
        total += used * price
        remaining -= used
    return total

def tien_phai_tra(ten, chi_truoc, chi_nay):
    if chi_nay < chi_truoc:
        raise ValueError("Chỉ số tháng này phải >= chỉ số tháng trước.")
    kwh = chi_nay - chi_truoc
    tien_truoc_vat = tinh_tien_truoc_vat(kwh)
    tien_co_vat = round(tien_truoc_vat * 1.08)  # làm tròn tới đơn vị đồng
    return f"Ho va ten: {ten}\nTien phai tra la: {tien_co_vat}"

# Ví dụ sử dụng (chép hoặc đổi giá trị theo ý bạn):
if __name__ == "__main__":
    # Ví dụ 1
    print(tien_phai_tra("Pham Xuan Toai", 1020, 1070))
    # Ví dụ 2
    print()
    print(tien_phai_tra("Nguyen Xuan Long", 2097, 2278))
    # Ví dụ 3
    print()
    print(tien_phai_tra("Nguyen Xuan Hai", 2000, 2586))

# %%
#Baitap_Bieuthuc_toantu_nhapxuat_dulieu
#W2A1
print('Hello World!')
# Out:
# Hello World!

# %%
#W2A2
a = input('Nhap ten cua ban')
print('Xin chao ',a)
# Out:
# Xin chao  dominhanh

# %%
#W2A3
a = float(input('Nhap so nguyen a:'))
b = float(input('Nhap so nguyen b:'))
tong_hai_so_nguyen = a + b
hieu_hai_so_nguyen = a - b
tich_hai_so_nguyen = a * b
thuong_hai_so_nguyen = a / b
thuong_hai_so_nguyen = round(thuong_hai_so_nguyen,2)
print('a + b =',tong_hai_so_nguyen)
print('a - b =',hieu_hai_so_nguyen)
print('a * b =',tich_hai_so_nguyen)
print('a / b =',thuong_hai_so_nguyen)
print('a',a)
print('b',b)
# Out:
# a + b = 45669.0
# a - b = 44799.0
# a * b = 19676790.0
# a / b = 103.99
# a 45234.0
# b 435.0

# %%
#W2A5
a,b = map(int,input().split())
a_luy_thua_b = a ** b
print('ket qua la:',a_luy_thua_b)
# Out:
# ket qua la: 32
